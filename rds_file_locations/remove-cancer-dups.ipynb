# %%
import pandas as pd

df = pd.read_csv("tcrseq_pbmcfnames.csv")
df
# Out:
#      Unnamed: 0                        filename   LTX_ID organ tissue region  \
# 0           389   dcr_LTX_064_PBMC_alpha.tsv.gz  LTX0064  PBMC   PBMC   PBMC
# 1           390    dcr_LTX_064_PBMC_beta.tsv.gz  LTX0064  PBMC   PBMC   PBMC
# 2           391  dcr_LTX_0185_PBMC_alpha.tsv.gz  LTX0185  PBMC   PBMC   PBMC
# 3           392   dcr_LTX_0185_PBMC_beta.tsv.gz  LTX0185  PBMC   PBMC   PBMC
# 4           393  dcr_LTX_0206_PBMC_alpha.tsv.gz  LTX0206  PBMC   PBMC   PBMC
# ..          ...                             ...      ...   ...    ...    ...
# 176         565        dcr_36PBMCs_alpha.tsv.gz  LTX0036  PBMC   PBMC   PBMC
# 177         566         dcr_36PBMCs_beta.tsv.gz  LTX0036  PBMC   PBMC   PBMC
# 178         567      dcr_079_PBMCs_alpha.tsv.gz  LTX0079  PBMC   PBMC   PBMC
# 179         568       dcr_079_PBMCs_beta.tsv.gz  LTX0079  PBMC   PBMC   PBMC
# 180         569     dcr_alpha_82_PBMCs_a.tsv.gz  LTX0082  PBMC   PBMC   PBMC
#
#     timepoint  chain repeat  notes
# 0          SU  alpha    NaN    NaN
# 1          SU   beta    NaN    NaN
# 2          SU  alpha    NaN    NaN
# 3          SU   beta    NaN    NaN
# 4          SU  alpha    NaN    NaN
# ..        ...    ...    ...    ...
# 176        SU  alpha    NaN    NaN
# 177        SU   beta    NaN    NaN
# 178        SU  alpha    NaN    NaN
# 179        SU   beta    NaN    NaN
# 180        SU  alpha    NaN    NaN
#
# [181 rows x 10 columns]

# %%
dups = df["LTX_ID"].value_counts().index[(df["LTX_ID"].value_counts() > 2).values]
dups
# Out:
# Index(['LTX0102', 'LTX0210', 'LTX0674', 'LTX0135', 'LTX0272', 'LTX0306',
#        'LTX0310', 'LTX0080'],
#       dtype='object', name='LTX_ID')

# %%
to_discard = []

for i in dups:
    repeats = df.loc[df["LTX_ID"] == i]["filename"].tolist()
    to_discard += [i for i in repeats if "merge" not in i]

to_discard
# Out:
# ['dcr_LTX_0102_PBMC_alpha.tsv.gz',
#  'dcr_LTX_0102_PBMC_beta.tsv.gz',
#  'dcr_LTX_0102_PBMCrpt_alpha.tsv.gz',
#  'dcr_LTX_0102_PBMCrpt_beta.tsv.gz',
#  'dcr_LTX_0210_PBMC_alpha.tsv.gz',
#  'dcr_LTX_0210_PBMC_beta.tsv.gz',
#  'dcr_LTX_0210_PBMCrpt_alpha.tsv.gz',
#  'dcr_LTX_0210_PBMCrpt_beta.tsv.gz',
#  'dcr_LTX_0674_PBMC_alpha.tsv.gz',
#  'dcr_LTX_0674_PBMC_beta.tsv.gz',
#  'dcr_LTX_0674_PBMCrpt_alpha.tsv.gz',
#  'dcr_LTX_0674_PBMCrpt_beta.tsv.gz',
#  'dcr_LTX_0135_PBMC_alpha.tsv.gz',
#  'dcr_LTX_0135_PBMC_beta.tsv.gz',
#  'dcr_LTX_0135_PBMCrpt_alpha.tsv.gz',
#  'dcr_LTX_0135_PBMCrpt_beta.tsv.gz',
#  'dcr_LTX_0272_PBMC_alpha.tsv.gz',
#  'dcr_LTX_0272_PBMC_beta.tsv.gz',
#  'dcr_LTX_0272_PBMCrpt_alpha.tsv.gz',
#  'dcr_LTX_0272_PBMCrpt_beta.tsv.gz',
#  'dcr_LTX_0306_PBMC_alpha.tsv.gz',
#  'dcr_LTX_0306_PBMC_beta.tsv.gz',
#  'dcr_LTX_0306_PBMCrpt_alpha.tsv.gz',
#  'dcr_LTX_0306_PBMCrpt_beta.tsv.gz',
#  'dcr_LTX_0310_PBMC_alpha.tsv.gz',
#  'dcr_LTX_0310_PBMC_beta.tsv.gz',
#  'dcr_LTX_0310_PBMCrpt_alpha.tsv.gz',
#  'dcr_LTX_0310_PBMCrpt_beta.tsv.gz',
#  'dcr_LTX_0080_PBMC_alpha.tsv.gz',
#  'dcr_LTX_0080_PBMC_beta.tsv.gz',
#  'dcr_LTX_0080_PBMCrpt_alpha.tsv.gz',
#  'dcr_LTX_0080_PBMCrpt_beta.tsv.gz']

# %%
from pathlib import Path
import os

directory = Path.cwd().parent / "data" / "trimmed" / "pbmc_cancer"

for i in to_discard:
    fname = i.replace(".gz", "")
    try:
        os.remove(directory / fname)
    except FileNotFoundError as e:
        print (f"{directory / fname} not found")
# Out:
# c:\Users\rcwyuen\OneDrive - University College London\Academic\Year 4 2023-2024\Y4 COMP0138 Dissertation\Code\TCR-Cancer-Prediction\data\trimmed\pbmc_cancer\dcr_LTX_0102_PBMC_alpha.tsv not found
# c:\Users\rcwyuen\OneDrive - University College London\Academic\Year 4 2023-2024\Y4 COMP0138 Dissertation\Code\TCR-Cancer-Prediction\data\trimmed\pbmc_cancer\dcr_LTX_0102_PBMC_beta.tsv not found
# c:\Users\rcwyuen\OneDrive - University College London\Academic\Year 4 2023-2024\Y4 COMP0138 Dissertation\Code\TCR-Cancer-Prediction\data\trimmed\pbmc_cancer\dcr_LTX_0102_PBMCrpt_alpha.tsv not found
# c:\Users\rcwyuen\OneDrive - University College London\Academic\Year 4 2023-2024\Y4 COMP0138 Dissertation\Code\TCR-Cancer-Prediction\data\trimmed\pbmc_cancer\dcr_LTX_0102_PBMCrpt_beta.tsv not found
